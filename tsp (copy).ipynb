# %%
from networkx import *
from pyevolve import G1DList
from pyevolve import GSimpleGA
from pyevolve import Mutators
from pyevolve import Initializators
from pyevolve import Crossovers
from pyevolve import Consts

import random

# %%
def TourInitializator(gnome , **args):
    global G
    gnome.clearList()
    lst=[i for i in xrange(len(G))]
    for i in xrange(len(G)):
        choice = random.choice(lst)
        lst.remove(choice)
        gnome.append(choice)

# %%
def eval_func(tour):
    global G
    total = 0
    num_cities = len(tour)
    for i in xrange(num_cities):
        j = (i+1) % num_cities
        city_i=tour[i]
        city_j=tour[j]
        total += G[city_i][city_j]['length']
    return total

# %%
random.seed()
G=complete_graph(50)
for i,j in G.edges():
    G[i][j]['length']=random.randint(1 , 10000)

# %%
# Out:
# 4224

# %%
gnome = G1DList.G1DList(len(G))
gnome.evaluator.set(eval_func)
gnome.mutator.set(Mutators.G1DListMutatorSwap)

# %%
ga = GSimpleGA.GSimpleGA(genome)
ga.setGenerations(200000)
ga.setMinimax(Consts.minimaxType["minimize"])
ga.setCrossoverRate(1.0)
ga.setMutationRate(0.02)
ga.setPopulationSize(80)


ga.evolve(freq_stats=500)
best = ga.bestIndividual()
# Out:
# Gen. 0 (0.00%): Max/Min/Avg Fitness(Raw) [3.00(5.00)/2.10(0.50)/2.50(2.50)]
# Gen. 500 (0.25%): Max/Min/Avg Fitness(Raw) [0.67(1.00)/0.54(0.50)/0.56(0.56)]
# Gen. 1000 (0.50%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 1500 (0.75%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 2000 (1.00%): Max/Min/Avg Fitness(Raw) [0.64(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 2500 (1.25%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 3000 (1.50%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 3500 (1.75%): Max/Min/Avg Fitness(Raw) [0.68(1.00)/0.55(0.50)/0.56(0.56)]
# Gen. 4000 (2.00%): Max/Min/Avg Fitness(Raw) [0.61(1.00)/0.51(0.50)/0.51(0.51)]
# Gen. 4500 (2.25%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 5000 (2.50%): Max/Min/Avg Fitness(Raw) [0.64(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 5500 (2.75%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 6000 (3.00%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 6500 (3.25%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 7000 (3.50%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 7500 (3.75%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.56(0.56)]
# Gen. 8000 (4.00%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 8500 (4.25%): Max/Min/Avg Fitness(Raw) [0.64(1.50)/0.53(0.50)/0.53(0.53)]
# Gen. 9000 (4.50%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.53(0.50)/0.54(0.54)]
# Gen. 9500 (4.75%): Max/Min/Avg Fitness(Raw) [0.69(1.00)/0.55(0.50)/0.57(0.57)]
# Gen. 10000 (5.00%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.56(0.56)]
# Gen. 10500 (5.25%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 11000 (5.50%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.56(0.56)]
# Gen. 11500 (5.75%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 12000 (6.00%): Max/Min/Avg Fitness(Raw) [0.63(1.50)/0.52(0.50)/0.52(0.53)]
# Gen. 12500 (6.25%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.53(0.50)/0.54(0.54)]
# Gen. 13000 (6.50%): Max/Min/Avg Fitness(Raw) [0.70(1.50)/0.58(0.50)/0.59(0.59)]
# Gen. 13500 (6.75%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.53(0.50)/0.54(0.54)]
# Gen. 14000 (7.00%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 14500 (7.25%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 15000 (7.50%): Max/Min/Avg Fitness(Raw) [0.61(1.00)/0.51(0.50)/0.51(0.51)]
# Gen. 15500 (7.75%): Max/Min/Avg Fitness(Raw) [0.67(1.00)/0.54(0.50)/0.56(0.56)]
# Gen. 16000 (8.00%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 16500 (8.25%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 17000 (8.50%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 17500 (8.75%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.53(0.50)/0.54(0.54)]
# Gen. 18000 (9.00%): Max/Min/Avg Fitness(Raw) [0.61(1.00)/0.50(0.50)/0.51(0.51)]
# Gen. 18500 (9.25%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 19000 (9.50%): Max/Min/Avg Fitness(Raw) [0.69(1.50)/0.57(0.50)/0.58(0.57)]
# Gen. 19500 (9.75%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.53(0.50)/0.54(0.54)]
# Gen. 20000 (10.00%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 20500 (10.25%): Max/Min/Avg Fitness(Raw) [0.69(1.50)/0.57(0.50)/0.58(0.57)]
# Gen. 21000 (10.50%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 21500 (10.75%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.56(0.56)]
# Gen. 22000 (11.00%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 22500 (11.25%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.56(0.56)]
# Gen. 23000 (11.50%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 23500 (11.75%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.56(0.56)]
# Gen. 24000 (12.00%): Max/Min/Avg Fitness(Raw) [0.69(1.50)/0.57(0.50)/0.58(0.57)]
# Gen. 24500 (12.25%): Max/Min/Avg Fitness(Raw) [0.67(1.00)/0.54(0.50)/0.56(0.56)]
# Gen. 25000 (12.50%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 25500 (12.75%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.57(0.57)]
# Gen. 26000 (13.00%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 26500 (13.25%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 27000 (13.50%): Max/Min/Avg Fitness(Raw) [0.67(2.00)/0.55(0.50)/0.56(0.56)]
# Gen. 27500 (13.75%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 28000 (14.00%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 28500 (14.25%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.57(0.57)]
# Gen. 29000 (14.50%): Max/Min/Avg Fitness(Raw) [0.62(1.50)/0.52(0.50)/0.52(0.52)]
# Gen. 29500 (14.75%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 30000 (15.00%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 30500 (15.25%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 31000 (15.50%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 31500 (15.75%): Max/Min/Avg Fitness(Raw) [0.64(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 32000 (16.00%): Max/Min/Avg Fitness(Raw) [0.61(1.00)/0.51(0.50)/0.51(0.51)]
# Gen. 32500 (16.25%): Max/Min/Avg Fitness(Raw) [0.61(1.00)/0.51(0.50)/0.51(0.51)]
# Gen. 33000 (16.50%): Max/Min/Avg Fitness(Raw) [0.70(2.00)/0.58(0.50)/0.59(0.59)]
# Gen. 33500 (16.75%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 34000 (17.00%): Max/Min/Avg Fitness(Raw) [0.66(1.00)/0.54(0.50)/0.55(0.55)]
# Gen. 34500 (17.25%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.57(0.57)]
# Gen. 35000 (17.50%): Max/Min/Avg Fitness(Raw) [0.71(1.00)/0.56(0.50)/0.59(0.59)]
# Gen. 35500 (17.75%): Max/Min/Avg Fitness(Raw) [0.70(1.50)/0.58(0.50)/0.59(0.59)]
# Gen. 36000 (18.00%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 36500 (18.25%): Max/Min/Avg Fitness(Raw) [0.61(1.00)/0.51(0.50)/0.51(0.51)]
# Gen. 37000 (18.50%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 37500 (18.75%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 38000 (19.00%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 38500 (19.25%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 39000 (19.50%): Max/Min/Avg Fitness(Raw) [0.64(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 39500 (19.75%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.57(0.57)]
# Gen. 40000 (20.00%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.53(0.50)/0.54(0.54)]
# Gen. 40500 (20.25%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 41000 (20.50%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 41500 (20.75%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 42000 (21.00%): Max/Min/Avg Fitness(Raw) [0.68(1.00)/0.55(0.50)/0.57(0.57)]
# Gen. 42500 (21.25%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 43000 (21.50%): Max/Min/Avg Fitness(Raw) [0.70(1.50)/0.58(0.50)/0.59(0.59)]
# Gen. 43500 (21.75%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 44000 (22.00%): Max/Min/Avg Fitness(Raw) [0.64(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 44500 (22.25%): Max/Min/Avg Fitness(Raw) [0.70(2.00)/0.57(0.50)/0.58(0.58)]
# Gen. 45000 (22.50%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 45500 (22.75%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 46000 (23.00%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.57(0.57)]
# Gen. 46500 (23.25%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 47000 (23.50%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 47500 (23.75%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.56(0.56)]
# Gen. 48000 (24.00%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 48500 (24.25%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 49000 (24.50%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.57(0.57)]
# Gen. 49500 (24.75%): Max/Min/Avg Fitness(Raw) [0.61(1.00)/0.51(0.50)/0.51(0.51)]
# Gen. 50000 (25.00%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.53(0.50)/0.54(0.54)]
# Gen. 50500 (25.25%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 51000 (25.50%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 51500 (25.75%): Max/Min/Avg Fitness(Raw) [0.66(2.00)/0.55(0.50)/0.55(0.55)]
# Gen. 52000 (26.00%): Max/Min/Avg Fitness(Raw) [0.64(1.50)/0.53(0.50)/0.53(0.53)]
# Gen. 52500 (26.25%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 53000 (26.50%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.56(0.56)]
# Gen. 53500 (26.75%): Max/Min/Avg Fitness(Raw) [0.64(1.50)/0.53(0.50)/0.53(0.53)]
# Gen. 54000 (27.00%): Max/Min/Avg Fitness(Raw) [0.66(2.00)/0.55(0.50)/0.55(0.55)]
# Gen. 54500 (27.25%): Max/Min/Avg Fitness(Raw) [0.69(1.50)/0.57(0.50)/0.58(0.57)]
# Gen. 55000 (27.50%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 55500 (27.75%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 56000 (28.00%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 56500 (28.25%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.56(0.56)]
# Gen. 57000 (28.50%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.53(0.50)/0.54(0.54)]
# Gen. 57500 (28.75%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 58000 (29.00%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 58500 (29.25%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 59000 (29.50%): Max/Min/Avg Fitness(Raw) [0.69(1.50)/0.57(0.50)/0.58(0.57)]
# Gen. 59500 (29.75%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 60000 (30.00%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.53(0.50)/0.54(0.54)]
# Gen. 60500 (30.25%): Max/Min/Avg Fitness(Raw) [0.64(1.50)/0.53(0.50)/0.53(0.53)]
# Gen. 61000 (30.50%): Max/Min/Avg Fitness(Raw) [0.63(1.50)/0.52(0.50)/0.52(0.53)]
# Gen. 61500 (30.75%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 62000 (31.00%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 62500 (31.25%): Max/Min/Avg Fitness(Raw) [0.69(1.50)/0.57(0.50)/0.58(0.57)]
# Gen. 63000 (31.50%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.56(0.56)]
# Gen. 63500 (31.75%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.57(0.57)]
# Gen. 64000 (32.00%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 64500 (32.25%): Max/Min/Avg Fitness(Raw) [0.64(1.50)/0.53(0.50)/0.53(0.53)]
# Gen. 65000 (32.50%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 65500 (32.75%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 66000 (33.00%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 66500 (33.25%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.57(0.57)]
# Gen. 67000 (33.50%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 67500 (33.75%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 68000 (34.00%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 68500 (34.25%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 69000 (34.50%): Max/Min/Avg Fitness(Raw) [0.66(1.00)/0.54(0.50)/0.55(0.55)]
# Gen. 69500 (34.75%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 70000 (35.00%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 70500 (35.25%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 71000 (35.50%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 71500 (35.75%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 72000 (36.00%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 72500 (36.25%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 73000 (36.50%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 73500 (36.75%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 74000 (37.00%): Max/Min/Avg Fitness(Raw) [0.69(1.00)/0.55(0.50)/0.57(0.57)]
# Gen. 74500 (37.25%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 75000 (37.50%): Max/Min/Avg Fitness(Raw) [0.64(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 75500 (37.75%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 76000 (38.00%): Max/Min/Avg Fitness(Raw) [0.67(1.00)/0.54(0.50)/0.56(0.56)]
# Gen. 76500 (38.25%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.53(0.50)/0.54(0.54)]
# Gen. 77000 (38.50%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 77500 (38.75%): Max/Min/Avg Fitness(Raw) [0.64(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 78000 (39.00%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 78500 (39.25%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.57(0.57)]
# Gen. 79000 (39.50%): Max/Min/Avg Fitness(Raw) [0.68(1.00)/0.55(0.50)/0.56(0.56)]
# Gen. 79500 (39.75%): Max/Min/Avg Fitness(Raw) [0.68(2.00)/0.56(0.50)/0.56(0.56)]
# Gen. 80000 (40.00%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 80500 (40.25%): Max/Min/Avg Fitness(Raw) [0.64(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 81000 (40.50%): Max/Min/Avg Fitness(Raw) [0.66(1.00)/0.54(0.50)/0.55(0.55)]
# Gen. 81500 (40.75%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 82000 (41.00%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 82500 (41.25%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 83000 (41.50%): Max/Min/Avg Fitness(Raw) [0.72(1.50)/0.59(0.50)/0.60(0.60)]
# Gen. 83500 (41.75%): Max/Min/Avg Fitness(Raw) [0.64(1.50)/0.53(0.50)/0.53(0.53)]
# Gen. 84000 (42.00%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 84500 (42.25%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 85000 (42.50%): Max/Min/Avg Fitness(Raw) [0.74(2.00)/0.61(0.50)/0.62(0.62)]
# Gen. 85500 (42.75%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 86000 (43.00%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 86500 (43.25%): Max/Min/Avg Fitness(Raw) [0.64(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 87000 (43.50%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 87500 (43.75%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 88000 (44.00%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.53(0.50)/0.54(0.54)]
# Gen. 88500 (44.25%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 89000 (44.50%): Max/Min/Avg Fitness(Raw) [0.68(2.00)/0.56(0.50)/0.57(0.57)]
# Gen. 89500 (44.75%): Max/Min/Avg Fitness(Raw) [0.66(1.00)/0.54(0.50)/0.55(0.55)]
# Gen. 90000 (45.00%): Max/Min/Avg Fitness(Raw) [0.64(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 90500 (45.25%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.57(0.57)]
# Gen. 91000 (45.50%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 91500 (45.75%): Max/Min/Avg Fitness(Raw) [0.68(2.50)/0.56(0.50)/0.57(0.57)]
# Gen. 92000 (46.00%): Max/Min/Avg Fitness(Raw) [0.64(1.50)/0.53(0.50)/0.53(0.53)]
# Gen. 92500 (46.25%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 93000 (46.50%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 93500 (46.75%): Max/Min/Avg Fitness(Raw) [0.61(1.00)/0.51(0.50)/0.51(0.51)]
# Gen. 94000 (47.00%): Max/Min/Avg Fitness(Raw) [0.65(2.00)/0.53(0.50)/0.54(0.54)]
# Gen. 94500 (47.25%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 95000 (47.50%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 95500 (47.75%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 96000 (48.00%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.57(0.57)]
# Gen. 96500 (48.25%): Max/Min/Avg Fitness(Raw) [0.64(1.50)/0.53(0.50)/0.53(0.53)]
# Gen. 97000 (48.50%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 97500 (48.75%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 98000 (49.00%): Max/Min/Avg Fitness(Raw) [0.66(1.00)/0.54(0.50)/0.55(0.55)]
# Gen. 98500 (49.25%): Max/Min/Avg Fitness(Raw) [0.63(1.50)/0.52(0.50)/0.52(0.53)]
# Gen. 99000 (49.50%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 99500 (49.75%): Max/Min/Avg Fitness(Raw) [0.65(2.00)/0.53(0.50)/0.54(0.54)]
# Gen. 100000 (50.00%): Max/Min/Avg Fitness(Raw) [0.70(1.00)/0.56(0.50)/0.58(0.58)]
# Gen. 100500 (50.25%): Max/Min/Avg Fitness(Raw) [0.65(2.00)/0.54(0.50)/0.54(0.54)]
# Gen. 101000 (50.50%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 101500 (50.75%): Max/Min/Avg Fitness(Raw) [0.69(1.50)/0.57(0.50)/0.58(0.57)]
# Gen. 102000 (51.00%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 102500 (51.25%): Max/Min/Avg Fitness(Raw) [0.68(2.00)/0.56(0.50)/0.57(0.57)]
# Gen. 103000 (51.50%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 103500 (51.75%): Max/Min/Avg Fitness(Raw) [0.65(2.00)/0.54(0.50)/0.54(0.54)]
# Gen. 104000 (52.00%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.56(0.56)]
# Gen. 104500 (52.25%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 105000 (52.50%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 105500 (52.75%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 106000 (53.00%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 106500 (53.25%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 107000 (53.50%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 107500 (53.75%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 108000 (54.00%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 108500 (54.25%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 109000 (54.50%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 109500 (54.75%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 110000 (55.00%): Max/Min/Avg Fitness(Raw) [0.70(1.50)/0.57(0.50)/0.58(0.58)]
# Gen. 110500 (55.25%): Max/Min/Avg Fitness(Raw) [0.70(1.50)/0.57(0.50)/0.58(0.58)]
# Gen. 111000 (55.50%): Max/Min/Avg Fitness(Raw) [0.69(2.00)/0.57(0.50)/0.57(0.57)]
# Gen. 111500 (55.75%): Max/Min/Avg Fitness(Raw) [0.68(1.00)/0.55(0.50)/0.56(0.56)]
# Gen. 112000 (56.00%): Max/Min/Avg Fitness(Raw) [0.61(1.00)/0.51(0.50)/0.51(0.51)]
# Gen. 112500 (56.25%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.57(0.57)]
# Gen. 113000 (56.50%): Max/Min/Avg Fitness(Raw) [0.64(1.50)/0.53(0.50)/0.53(0.53)]
# Gen. 113500 (56.75%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.57(0.57)]
# Gen. 114000 (57.00%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 114500 (57.25%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.57(0.57)]
# Gen. 115000 (57.50%): Max/Min/Avg Fitness(Raw) [0.63(1.50)/0.52(0.50)/0.52(0.53)]
# Gen. 115500 (57.75%): Max/Min/Avg Fitness(Raw) [0.70(1.50)/0.57(0.50)/0.58(0.58)]
# Gen. 116000 (58.00%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.57(0.57)]
# Gen. 116500 (58.25%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 117000 (58.50%): Max/Min/Avg Fitness(Raw) [0.63(1.50)/0.52(0.50)/0.52(0.53)]
# Gen. 117500 (58.75%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 118000 (59.00%): Max/Min/Avg Fitness(Raw) [0.63(2.00)/0.52(0.50)/0.53(0.53)]
# Gen. 118500 (59.25%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 119000 (59.50%): Max/Min/Avg Fitness(Raw) [0.66(1.00)/0.54(0.50)/0.55(0.55)]
# Gen. 119500 (59.75%): Max/Min/Avg Fitness(Raw) [0.66(1.00)/0.54(0.50)/0.55(0.55)]
# Gen. 120000 (60.00%): Max/Min/Avg Fitness(Raw) [0.70(1.50)/0.57(0.50)/0.58(0.58)]
# Gen. 120500 (60.25%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 121000 (60.50%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 121500 (60.75%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.53(0.50)/0.54(0.54)]
# Gen. 122000 (61.00%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 122500 (61.25%): Max/Min/Avg Fitness(Raw) [0.68(2.00)/0.56(0.50)/0.56(0.56)]
# Gen. 123000 (61.50%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 123500 (61.75%): Max/Min/Avg Fitness(Raw) [0.68(1.00)/0.55(0.50)/0.57(0.57)]
# Gen. 124000 (62.00%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 124500 (62.25%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 125000 (62.50%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 125500 (62.75%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 126000 (63.00%): Max/Min/Avg Fitness(Raw) [0.69(1.50)/0.57(0.50)/0.58(0.57)]
# Gen. 126500 (63.25%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 127000 (63.50%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.53(0.50)/0.54(0.54)]
# Gen. 127500 (63.75%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 128000 (64.00%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 128500 (64.25%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.53(0.50)/0.54(0.54)]
# Gen. 129000 (64.50%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 129500 (64.75%): Max/Min/Avg Fitness(Raw) [0.64(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 130000 (65.00%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 130500 (65.25%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 131000 (65.50%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.57(0.57)]
# Gen. 131500 (65.75%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 132000 (66.00%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 132500 (66.25%): Max/Min/Avg Fitness(Raw) [0.61(1.00)/0.51(0.50)/0.51(0.51)]
# Gen. 133000 (66.50%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 133500 (66.75%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 134000 (67.00%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 134500 (67.25%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 135000 (67.50%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 135500 (67.75%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 136000 (68.00%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 136500 (68.25%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 137000 (68.50%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 137500 (68.75%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.56(0.56)]
# Gen. 138000 (69.00%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 138500 (69.25%): Max/Min/Avg Fitness(Raw) [0.69(1.50)/0.57(0.50)/0.58(0.57)]
# Gen. 139000 (69.50%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 139500 (69.75%): Max/Min/Avg Fitness(Raw) [0.71(2.00)/0.59(0.50)/0.59(0.59)]
# Gen. 140000 (70.00%): Max/Min/Avg Fitness(Raw) [0.71(1.50)/0.58(0.50)/0.59(0.59)]
# Gen. 140500 (70.25%): Max/Min/Avg Fitness(Raw) [0.64(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 141000 (70.50%): Max/Min/Avg Fitness(Raw) [0.67(1.00)/0.54(0.50)/0.56(0.56)]
# Gen. 141500 (70.75%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 142000 (71.00%): Max/Min/Avg Fitness(Raw) [0.69(1.50)/0.57(0.50)/0.58(0.57)]
# Gen. 142500 (71.25%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 143000 (71.50%): Max/Min/Avg Fitness(Raw) [0.70(1.50)/0.58(0.50)/0.59(0.59)]
# Gen. 143500 (71.75%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 144000 (72.00%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.56(0.56)]
# Gen. 144500 (72.25%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.52(0.53)]
# Gen. 145000 (72.50%): Max/Min/Avg Fitness(Raw) [0.64(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 145500 (72.75%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 146000 (73.00%): Max/Min/Avg Fitness(Raw) [0.65(2.00)/0.54(0.50)/0.54(0.54)]
# Gen. 146500 (73.25%): Max/Min/Avg Fitness(Raw) [0.64(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 147000 (73.50%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 147500 (73.75%): Max/Min/Avg Fitness(Raw) [0.63(1.50)/0.52(0.50)/0.52(0.53)]
# Gen. 148000 (74.00%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 148500 (74.25%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 149000 (74.50%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 149500 (74.75%): Max/Min/Avg Fitness(Raw) [0.62(1.50)/0.52(0.50)/0.52(0.52)]
# Gen. 150000 (75.00%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.56(0.56)]
# Gen. 150500 (75.25%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 151000 (75.50%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 151500 (75.75%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 152000 (76.00%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.57(0.57)]
# Gen. 152500 (76.25%): Max/Min/Avg Fitness(Raw) [0.64(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 153000 (76.50%): Max/Min/Avg Fitness(Raw) [0.64(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 153500 (76.75%): Max/Min/Avg Fitness(Raw) [0.64(1.50)/0.53(0.50)/0.53(0.53)]
# Gen. 154000 (77.00%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 154500 (77.25%): Max/Min/Avg Fitness(Raw) [0.64(1.50)/0.53(0.50)/0.53(0.53)]
# Gen. 155000 (77.50%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 155500 (77.75%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 156000 (78.00%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 156500 (78.25%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 157000 (78.50%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 157500 (78.75%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 158000 (79.00%): Max/Min/Avg Fitness(Raw) [0.67(2.00)/0.55(0.50)/0.56(0.56)]
# Gen. 158500 (79.25%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 159000 (79.50%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.56(0.56)]
# Gen. 159500 (79.75%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.53(0.50)/0.54(0.54)]
# Gen. 160000 (80.00%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 160500 (80.25%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 161000 (80.50%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 161500 (80.75%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.57(0.57)]
# Gen. 162000 (81.00%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 162500 (81.25%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 163000 (81.50%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.53(0.50)/0.54(0.54)]
# Gen. 163500 (81.75%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 164000 (82.00%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 164500 (82.25%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.57(0.57)]
# Gen. 165000 (82.50%): Max/Min/Avg Fitness(Raw) [0.70(1.50)/0.57(0.50)/0.58(0.58)]
# Gen. 165500 (82.75%): Max/Min/Avg Fitness(Raw) [0.68(2.00)/0.56(0.50)/0.57(0.57)]
# Gen. 166000 (83.00%): Max/Min/Avg Fitness(Raw) [0.69(1.50)/0.57(0.50)/0.57(0.57)]
# Gen. 166500 (83.25%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 167000 (83.50%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 167500 (83.75%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 168000 (84.00%): Max/Min/Avg Fitness(Raw) [0.64(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 168500 (84.25%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.56(0.56)]
# Gen. 169000 (84.50%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 169500 (84.75%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.53(0.50)/0.54(0.54)]
# Gen. 170000 (85.00%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 170500 (85.25%): Max/Min/Avg Fitness(Raw) [0.64(1.50)/0.53(0.50)/0.53(0.53)]
# Gen. 171000 (85.50%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.56(0.56)]
# Gen. 171500 (85.75%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.56(0.56)]
# Gen. 172000 (86.00%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 172500 (86.25%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 173000 (86.50%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 173500 (86.75%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 174000 (87.00%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 174500 (87.25%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 175000 (87.50%): Max/Min/Avg Fitness(Raw) [0.64(1.50)/0.53(0.50)/0.53(0.53)]
# Gen. 175500 (87.75%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 176000 (88.00%): Max/Min/Avg Fitness(Raw) [0.66(1.00)/0.54(0.50)/0.55(0.55)]
# Gen. 176500 (88.25%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.53(0.50)/0.54(0.54)]
# Gen. 177000 (88.50%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.53(0.50)/0.54(0.54)]
# Gen. 177500 (88.75%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 178000 (89.00%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 178500 (89.25%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.53(0.50)/0.54(0.54)]
# Gen. 179000 (89.50%): Max/Min/Avg Fitness(Raw) [0.64(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 179500 (89.75%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 180000 (90.00%): Max/Min/Avg Fitness(Raw) [0.67(1.00)/0.54(0.50)/0.56(0.56)]
# Gen. 180500 (90.25%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 181000 (90.50%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 181500 (90.75%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 182000 (91.00%): Max/Min/Avg Fitness(Raw) [0.70(2.00)/0.57(0.50)/0.58(0.58)]
# Gen. 182500 (91.25%): Max/Min/Avg Fitness(Raw) [0.66(1.00)/0.54(0.50)/0.55(0.55)]
# Gen. 183000 (91.50%): Max/Min/Avg Fitness(Raw) [0.64(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 183500 (91.75%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 184000 (92.00%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.57(0.57)]
# Gen. 184500 (92.25%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 185000 (92.50%): Max/Min/Avg Fitness(Raw) [0.67(1.00)/0.54(0.50)/0.56(0.56)]
# Gen. 185500 (92.75%): Max/Min/Avg Fitness(Raw) [0.64(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 186000 (93.00%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 186500 (93.25%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.56(0.56)]
# Gen. 187000 (93.50%): Max/Min/Avg Fitness(Raw) [0.66(1.50)/0.54(0.50)/0.55(0.55)]
# Gen. 187500 (93.75%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.56(0.56)]
# Gen. 188000 (94.00%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 188500 (94.25%): Max/Min/Avg Fitness(Raw) [0.62(1.00)/0.51(0.50)/0.52(0.52)]
# Gen. 189000 (94.50%): Max/Min/Avg Fitness(Raw) [0.65(1.50)/0.54(0.50)/0.54(0.54)]
# Gen. 189500 (94.75%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.52(0.53)]
# Gen. 190000 (95.00%): Max/Min/Avg Fitness(Raw) [0.69(1.50)/0.57(0.50)/0.58(0.57)]
# Gen. 190500 (95.25%): Max/Min/Avg Fitness(Raw) [0.61(1.00)/0.50(0.50)/0.51(0.51)]
# Gen. 191000 (95.50%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 191500 (95.75%): Max/Min/Avg Fitness(Raw) [0.68(1.00)/0.55(0.50)/0.56(0.56)]
# Gen. 192000 (96.00%): Max/Min/Avg Fitness(Raw) [0.63(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 192500 (96.25%): Max/Min/Avg Fitness(Raw) [0.64(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 193000 (96.50%): Max/Min/Avg Fitness(Raw) [0.67(1.00)/0.54(0.50)/0.56(0.56)]
# Gen. 193500 (96.75%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Gen. 194000 (97.00%): Max/Min/Avg Fitness(Raw) [0.69(1.50)/0.57(0.50)/0.58(0.57)]
# Gen. 194500 (97.25%): Max/Min/Avg Fitness(Raw) [0.68(2.00)/0.56(0.50)/0.57(0.57)]
# Gen. 195000 (97.50%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.56(0.56)]
# Gen. 195500 (97.75%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 196000 (98.00%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 196500 (98.25%): Max/Min/Avg Fitness(Raw) [0.70(1.50)/0.58(0.50)/0.59(0.59)]
# Gen. 197000 (98.50%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.57(0.57)]
# Gen. 197500 (98.75%): Max/Min/Avg Fitness(Raw) [0.65(1.00)/0.53(0.50)/0.54(0.54)]
# Gen. 198000 (99.00%): Max/Min/Avg Fitness(Raw) [0.68(1.50)/0.56(0.50)/0.56(0.56)]
# Gen. 198500 (99.25%): Max/Min/Avg Fitness(Raw) [0.64(1.00)/0.52(0.50)/0.53(0.53)]
# Gen. 199000 (99.50%): Max/Min/Avg Fitness(Raw) [0.69(1.50)/0.57(0.50)/0.58(0.57)]
# Gen. 199500 (99.75%): Max/Min/Avg Fitness(Raw) [0.64(1.50)/0.53(0.50)/0.53(0.53)]
# Gen. 200000 (100.00%): Max/Min/Avg Fitness(Raw) [0.67(1.50)/0.55(0.50)/0.56(0.56)]
# Total time elapsed: 658.454 seconds.

# %%
best
# Out:
# - GenomeBase
# 	Score:			 0.500000
# 	Fitness:		 0.549619
#
# 	Params:		 {'allele': - GAlleles
# 	Homogeneous:	 False
# 	List size:	 20
# 	Alleles:
#
# Allele for 0 position:
# - GAlleleRange
# 	Real:		 False
# 	Ranges Count:	 1
# 	Range List:
# 			 Range from [0] to [0]
#
# Allele for 1 position:
# - GAlleleRange
# 	Real:		 False
# 	Ranges Count:	 1
# 	Range List:
# 			 Range from [0] to [1]
#
# Allele for 2 position:
# - GAlleleRange
# 	Real:		 False
# 	Ranges Count:	 1
# 	Range List:
# 			 Range from [0] to [2]
#
# Allele for 3 position:
# - GAlleleRange
# 	Real:		 False
# 	Ranges Count:	 1
# 	Range List:
# 			 Range from [0] to [3]
#
# Allele for 4 position:
# - GAlleleRange
# 	Real:		 False
# 	Ranges Count:	 1
# 	Range List:
# 			 Range from [0] to [4]
#
# Allele for 5 position:
# - GAlleleRange
# 	Real:		 False
# 	Ranges Count:	 1
# 	Range List:
# 			 Range from [0] to [5]
#
# Allele for 6 position:
# - GAlleleRange
# 	Real:		 False
# 	Ranges Count:	 1
# 	Range List:
# 			 Range from [0] to [6]
#
# Allele for 7 position:
# - GAlleleRange
# 	Real:		 False
# 	Ranges Count:	 1
# 	Range List:
# 			 Range from [0] to [7]
#
# Allele for 8 position:
# - GAlleleRange
# 	Real:		 False
# 	Ranges Count:	 1
# 	Range List:
# 			 Range from [0] to [8]
#
# Allele for 9 position:
# - GAlleleRange
# 	Real:		 False
# 	Ranges Count:	 1
# 	Range List:
# 			 Range from [0] to [9]
#
# Allele for 10 position:
# - GAlleleRange
# 	Real:		 False
# 	Ranges Count:	 1
# 	Range List:
# 			 Range from [0] to [10]
#
# Allele for 11 position:
# - GAlleleList
# 	List size:	 5
# 	Allele Options:	 ['a', 'b', 'xxx', 666, 0]
#
# Allele for 12 position:
# - GAlleleList
# 	List size:	 5
# 	Allele Options:	 ['a', 'b', 'xxx', 666, 0]
#
# Allele for 13 position:
# - GAlleleList
# 	List size:	 5
# 	Allele Options:	 ['a', 'b', 'xxx', 666, 0]
#
# Allele for 14 position:
# - GAlleleList
# 	List size:	 5
# 	Allele Options:	 ['a', 'b', 'xxx', 666, 0]
#
# Allele for 15 position:
# - GAlleleList
# 	List size:	 5
# 	Allele Options:	 ['a', 'b', 'xxx', 666, 0]
#
# Allele for 16 position:
# - GAlleleList
# 	List size:	 5
# 	Allele Options:	 ['a', 'b', 'xxx', 666, 0]
#
# Allele for 17 position:
# - GAlleleList
# 	List size:	 5
# 	Allele Options:	 ['a', 'b', 'xxx', 666, 0]
#
# Allele for 18 position:
# - GAlleleList
# 	List size:	 5
# 	Allele Options:	 ['a', 'b', 'xxx', 666, 0]
#
# Allele for 19 position:
# - GAlleleList
# 	List size:	 5
# 	Allele Options:	 ['a', 'b', 'xxx', 666, 0]
#
# }
#
# 	Slot [Evaluator] (Count: 1)
# 		Name: eval_func - Weight: 0.50
# 	Slot [Initializator] (Count: 1)
# 		Name: G1DListInitializatorAllele - Weight: 0.50
# 		Doc:  Allele initialization function of G1DList
#
#    To use this initializator, you must specify the *allele* genome parameter with the
#    :class:`GAllele.GAlleles` instance.
#
#
# 	Slot [Mutator] (Count: 1)
# 		Name: G1DListMutatorAllele - Weight: 0.50
# 		Doc:  The mutator of G1DList, Allele Mutator
#
#    To use this mutator, you must specify the *allele* genome parameter with the
#    :class:`GAllele.GAlleles` instance.
#
#
# 	Slot [Crossover] (Count: 1)
# 		Name: G1DListCrossoverSinglePoint - Weight: 0.50
# 		Doc:  The crossover of G1DList, Single Point
#
#    .. warning:: You can't use this crossover method for lists with just one element.
#
#
#
# - G1DList
# 	List size:	 20
# 	List:		 [0, 1, 1, 3, 4, 1, 2, 4, 1, 5, 4, 666, 'a', 'b', 'xxx', 'a', 'b', 'a', 'xxx', 'b']

# %%
def write_tour_to_img(coords, tour, img_file):
    padding=20
    coords=[(x+padding,y+padding) for (x,y) in coords]
    maxx,maxy=0,0
    for x,y in coords:
        maxx, maxy = max(x,maxx), max(y,maxy)
    maxx+=padding
    maxy+=padding
    img=Image.new("RGB",(int(maxx),int(maxy)),color=(255,255,255))
    font=ImageFont.load_default()
    d=ImageDraw.Draw(img);
    num_cities=len(tour)
    for i in range(num_cities):
        j=(i+1)%num_cities
        city_i=tour[i]
        city_j=tour[j]
        x1,y1=coords[city_i]
        x2,y2=coords[city_j]
        d.line((int(x1),int(y1),int(x2),int(y2)),fill=(0,0,0))
        d.text((int(x1)+7,int(y1)-5),str(i),font=font,fill=(32,32,32))

    for x,y in coords:
        x,y=int(x),int(y)
        d.ellipse((x-5,y-5,x+5,y+5),outline=(0,0,0),fill=(196,196,196))
    del d
    img.save(img_file, "PNG")
    print "The plot was saved into the %s file." % (img_file,)

# %%
write_tour_to_img(coords, best, "tsp_result.png")
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-66-045736bf674d> in <module>()
# ----> 1 write_tour_to_img(coords, best, "tsp_result.png")
#
# NameError: name 'coords' is not defined

# %%
from pyevolve import G1DList, GAllele
from pyevolve import GSimpleGA
from pyevolve import Mutators
from pyevolve import Crossovers
from pyevolve import Consts

import sys, random
random.seed(1024)
from math import sqrt

# %%
from PIL import Image, ImageDraw, ImageFont

# %%
def cartesian_matrix(coords):
    matrix={}
    for i,(x1,y1) in enumerate(coords):
        for j,(x2,y2) in enumerate(coords):
            dx, dy = x1-x2, y1-y2
            dist=sqrt(dx*dx + dy*dy)
            matrix[i,j] = dist
    return matrix

def tour_length(matrix, tour):
    total = 0
    t = tour.getInternalList()
    for i in range(CITIES):
        j      = (i+1)%CITIES
        total += matrix[t[i], t[j]]
    return total


def write_tour_to_img(coords, tour, img_file):
    padding=20
    coords=[(x+padding,y+padding) for (x,y) in coords]
    maxx,maxy=0,0
    for x,y in coords:
        maxx, maxy = max(x,maxx), max(y,maxy)
    maxx+=padding
    maxy+=padding
    img=Image.new("RGB",(int(maxx),int(maxy)),color=(255,255,255))
    font=ImageFont.load_default()
    d=ImageDraw.Draw(img);
    num_cities=len(tour)
    for i in range(num_cities):
        j=(i+1)%num_cities
        city_i=tour[i]
        city_j=tour[j]
        x1,y1=coords[city_i]
        x2,y2=coords[city_j]
        d.line((int(x1),int(y1),int(x2),int(y2)),fill=(0,0,0))
        d.text((int(x1)+7,int(y1)-5),str(i),font=font,fill=(32,32,32))

    for x,y in coords:
        x,y=int(x),int(y)
        d.ellipse((x-5,y-5,x+5,y+5),outline=(0,0,0),fill=(196,196,196))
    del d
    img.save(img_file, "PNG")
    print "The plot was saved into the %s file." % (img_file,)


def G1DListTSPInitializator(genome, **args):
   
    lst = [i for i in xrange(genome.getListSize())]
    random.shuffle(lst)
    genome.setInternalList(lst)

# This is to make a video of best individuals along the evolution
# Use mencoder to create a video with the file list list.txt
# mencoder mf://@list.txt -mf w=400:h=200:fps=3:type=png -ovc lavc
#          -lavcopts vcodec=mpeg4:mbd=2:trell -oac copy -o output.avi
#
def evolve_callback(ga_engine):
    global LAST_SCORE
    if ga_engine.getCurrentGeneration() % 100 == 0:
        best = ga_engine.bestIndividual()
        if LAST_SCORE != best.getRawScore():
            write_tour_to_img( coords, best, "tspimg/tsp_result_%d.png" % ga_engine.getCurrentGeneration())
            LAST_SCORE = best.getRawScore()
    return False

# %%
cm     = []
coords = []
CITIES = 100
WIDTH   = 1024
HEIGHT  = 768
LAST_SCORE = -1


global cm, coords, WIDTH, HEIGHT

coords = [(random.randint(0, WIDTH), random.randint(0, HEIGHT))
     for i in xrange(CITIES)]
cm     = cartesian_matrix(coords)
genome = G1DList.G1DList(len(coords))

genome.evaluator.set(lambda chromosome: tour_length(cm, chromosome))
genome.crossover.set(Crossovers.G1DListCrossoverEdge)
genome.initializator.set(G1DListTSPInitializator)

# 3662.69
ga = GSimpleGA.GSimpleGA(genome)
ga.setGenerations(200000)
ga.setMinimax(Consts.minimaxType["minimize"])
ga.setCrossoverRate(1.0)
ga.setMutationRate(0.02)
ga.setPopulationSize(80)

# # This is to make a video
# ga.stepCallback.set(evolve_callback)
# # 21666.49
# import psyco
# psyco.full()

ga.evolve(freq_stats=500)
best = ga.bestIndividual()


write_tour_to_img(coords, best, "tsp_result.png")
# Out:
# Gen. 0 (0.00%): Max/Min/Avg Fitness(Raw) [55853.83(50573.03)/36028.92(41994.42)/46544.86(46544.86)]
#
# 	A break was detected, you have interrupted the evolution !
#
# Gen. 388 (0.19%): Max/Min/Avg Fitness(Raw) [29077.96(27155.95)/18326.80(20668.61)/24231.63(24231.63)]
# Total time elapsed: 10.455 seconds.
# The plot was saved into the tsp_result.png file.
